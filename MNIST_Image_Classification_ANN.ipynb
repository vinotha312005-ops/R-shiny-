# %% [markdown]
# <a href="https://colab.research.google.com/github/vinotha312005-ops/R-shiny-/blob/main/MNIST_Image_Classification_ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **INTRODUCTION**
#
# This project focuses on classification handwritten digit immages using artificial neutraal network.The MNISTdataset which contains graphical image of digits from0 to 9. The model is implemented using python and eexecuted in goole colab.
#
#
#
# **OBJECTIVE**
#
# To classify handwrittern digit immages using a nueral network.To understand the working of fully connected neural networks.To evaluate model perfomance using accuracy.

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
(X_train, y_train), (X_test, y_test) = mnist.load_data()
print(X_train.shape)
print(y_train.shape)
X_train = X_train / 255.0
X_test = X_test / 255.0
X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
model = Sequential()

model.add(Dense(128, activation='relu', input_shape=(784,)))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
history = model.fit(
    X_train,
    y_train,
    epochs=10,
    batch_size=128,
    validation_split=0.2
)

test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test Accuracy:", test_accuracy)

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

prediction = model.predict(X_test[0].reshape(1,784))
print("Predicted Digit:", np.argmax(prediction))
# Out:
# (60000, 28, 28)
# (60000,)
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.7908 - loss: 0.7297 - val_accuracy: 0.9502 - val_loss: 0.1707
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9514 - loss: 0.1618 - val_accuracy: 0.9624 - val_loss: 0.1277
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9675 - loss: 0.1088 - val_accuracy: 0.9657 - val_loss: 0.1141
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9751 - loss: 0.0817 - val_accuracy: 0.9693 - val_loss: 0.1015
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9826 - loss: 0.0606 - val_accuracy: 0.9718 - val_loss: 0.0881
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9852 - loss: 0.0488 - val_accuracy: 0.9723 - val_loss: 0.0921
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9897 - loss: 0.0368 - val_accuracy: 0.9712 - val_loss: 0.0947
# Epoch 8/10
# ...

# %% [markdown]
# **CONCLUSION**
#
# The artifical neural was successfully trained on the MNIST dataset and achieved good classification accuracy .the results show that proper preprocessing and model training  help improve perfomance.This  project demondtrates the basic application of deep learning for imagr classification tasks.
